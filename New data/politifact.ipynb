# %%
#this script scrapes fake news from politifact.com 
inspiration: https://randerson112358.medium.com/scrape-a-political-website-for-fake-real-news-using-python-b4f5b2af830b

# %%
#Import the dependencies
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib.request
import time

# %%
#Create lists to store the scraped data

dates = []
statements = []

# %%
#Create a function to scrape the site
def scrape_website_Fake(page_number, rating):
    page_num = str(page_number) #Convert the page number to a string


    URL = 'https://www.politifact.com/factchecks/list/?page={}&category=coronavirus&ruling={}'.format(page_num, rating)


    webpage = requests.get(URL)  #Make a request to the website
    #time.sleep(3)
    soup = BeautifulSoup(webpage.text, "html.parser") #Parse the text from the website
    #Get the tags and it's class
    statement_footer =  soup.find_all('footer',attrs={'class':'m-statement__footer'})  #Get author and date
    statement_quote = soup.find_all('div', attrs={'class':'m-statement__quote'}) #Get the statement
    for i in statement_footer:
        link1 = i.text.strip()
        name_and_date = link1.split()
        month = name_and_date[4]
        day = name_and_date[5]
        year = name_and_date[6]
        date = month+' '+day+' '+year
        dates.append(date)
    #Loop through the div m-statement__quote
    for i in statement_quote:
        link2 = i.find_all('a')
        statements.append(link2[0].text.strip())

# %%
n=5
for i in range(1, n):
    scrape_website(i, rating="fake")

# %%
#Create dataFrame fake
FN = pd.DataFrame(columns = ['statement', 'date'])
FN['statement'] = statements
FN['date'] = dates
#Show the data set
print(FN)
# Out:
# Empty DataFrame
# Columns: [statement, date]
# Index: []

# %%
#Loop through 'n-1' webpages to scrape the data false
n=2
for i in range(1, n):
    scrape_website(i, rating="pants-fire")

# %%
#Loop through 'n-1' webpages to scrape the data pants-fire
#Create dataFrame pants-fire
PFN = pd.DataFrame(columns = ['statement', 'date'])
PFN['statement'] = statements
PFN['date'] = dates
#Show the data set
print(PFN)

# %%
from google.colab import drive
drive.mount('drive')

FN.to_csv('/content/drive/MyDrive/Final Project/COVID-fake-news-detection/New data/Data/FakeNews_raw.csv', encoding='utf-8', index=False)
# Out:
# Mounted at drive

# %%
PFN.to_csv('/content/drive/MyDrive/Final Project/COVID-fake-news-detection/New data/Data/Pants-fire_News_raw.csv', encoding='utf-8', index=False)

# %%
file1 = open("FakeNews_raw.csv", "a")
file2 = open("Pants_fire_News_raw.csv", "r")

for line in file2:
   file1.write(line)

file1.close()
file2.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-b1f318593255> in <module>()
# ----> 1 file1.to_csv('/content/drive/MyDrive/Final Project/COVID-fake-news-detection/New data/Data/FakeNews.csv', encoding='utf-8', index=False)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'to_csv'

# %%
#used some code chunks of https://github.com/mehranshakarami/AI_Spectrum/blob/main/2022/Twitter_API/twitter_data_search.py

# %%
import os
import tweepy as tw
import pandas as pd
from twitter_authentication import consumer_key
from twitter_authentication import consumer_secret
from twitter_authentication import access_token
from twitter_authentication import access_token_secret

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
#filter for user and then manually detect tweets that are not about covid and not english
# get tweets from specific user1

user = "WHO"
limit = 30

tweets = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets:
  print(tweet.full_text)
# Out:
# Endometriosis affects 1 in 10 women &amp; girls of reproductive age.
# Learn how to recognize it in the new #Endometriosis section on WHO’s women’s health chatbot on Viber.
# Let’s make sure everyone with endometriosis gets the diagnosis &amp; care they need https://t.co/I2M5paMBTE https://t.co/VdKwzf5Szb
# RT @WHOUkraine: .@WHO is providing generators to hospitals across #Ukraine with limited or no power supply to ensure the continuity of pati…
# RT @DrTedros: Namaste 🙏 Prime Minister @narendramodi, the pleasure was mine. Thank you, the government, and the people of #India for your s…
# RT @DrTedros: Pleased to meet #Mauritius Prime Minister @KumarJugnauth and discuss how 🇲🇺 can start introducing traditional medicine into i…
# RT @DrTedros: Devastated by the reports of attacks on schools in #Afghanistan yesterday. My heartfelt condolences go out to parents and fam…
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets:
    data.append([tweet.full_text])

df = pd.DataFrame(data, columns=columns)

print(df)
# Out:
#                                                 Tweet
# 0   Endometriosis affects 1 in 10 women &amp; girl...
# 1   RT @WHOUkraine: .@WHO is providing generators ...
# 2   RT @DrTedros: Namaste 🙏 Prime Minister @narend...
# 3   RT @DrTedros: Pleased to meet #Mauritius Prime...
# 4   RT @DrTedros: Devastated by the reports of att...
# 5   RT @DrTedros: By working together to make the ...
# 6   LIVE from #India 🇮🇳: @DrTedros’ address at the...
# 7   RT @DrTedros: Visited @AIIA_NDelhi, a role mod...
# 8   LIVE: Groundbreaking ceremony for the WHO Glob...
# 9   RT @DrTedros: Beautiful start to the day in #I...
# 10  RT @DrTedros: This is an urgent 🌍 challenge. 2...
# 11  .@DrTedros is traveling to #India for the grou...
# 12  RT @WHOEMRO: 99% of the world now lives in pol...
# 13  RT @WHOAFRO: Vaccines are safe and effective. ...
# 14  RT @WHOWPRO: Tobacco kills more than 8M people...
# 15  RT @PAHOCaribbean: Stay connected with your fa...
# ...

# %%
# get tweets from specific user2

user = "CDCgov"
limit = 30

tweets2 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets2:
  print(tweet.full_text)
# Out:
# CDC continues to recommend that people wear masks in all indoor public transportation settings. See full CDC statement:  https://t.co/xY9YcSlSxr
# RT @CDC_DASH: Young people need all the support we can give them, and schools serve as a critical venue to provide this support. #CDCABES h…
# RT @CDC_DASH: New CDC data shows the pandemic affected the #MentalHealth of high school students:
# ▪️2 in 5 students felt emotional distres…
# RT @CDC_DASH: School connectedness is one particularly powerful tool for mitigating the challenges adolescents have faced throughout the pa…
# As of April 18, 2022, national forecasts predict 200–4,000 new #COVID19 hospitalizations will likely be reported on May 13. More: https://t.co/Xys80ZGlxV. https://t.co/QyL0jWsuxD
# During Medical Laboratory Professionals Week, recognize &amp; celebrate the lab professionals in your life. 🔬
#
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets2:
    data.append([tweet.full_text])

df2 = pd.DataFrame(data, columns=columns)

print(df2)
# Out:
#                                                 Tweet
# 0   CDC continues to recommend that people wear ma...
# 1   As of April 18, 2022, national forecasts predi...
# 2   During Medical Laboratory Professionals Week, ...
# 3   #HCPs: The ACIP has new recommendations on Hep...
# 4   Why should you stay up to date with your #COVI...
# 5   #HCPs: Some of your littlest patients might ha...
# 6   Improvements to park, trail, and greenway infr...
# 7   #DYK? Your body’s ability to fight off #COVID1...
# 8   Health communicators &amp; data practitioners:...
# 9   #COVID19 can make some children very sick. A n...
# 10  Tele misused prescription #opioids from age 13...
# 11  #DYK that raw milk can have dangerous germs th...
# 12  As of April 18, 256.8 million people have rece...
# 13  Tribal community members, leaders, and partner...
# 14  Flying through @ATLairport between now &amp; A...
# 15  Over 9 million children ages 5–11 years have r...
# ...

# %%
# get tweets from specific user3

user = "CovidIndiaSeva"
limit = 30

tweets3 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets3:
  print(tweet.full_text)

# %%
columns = ['Tweet']
data = []

for tweet in tweets3:
    data.append([tweet.full_text])

df3 = pd.DataFrame(data, columns=columns)

print(df3)
# Out:
# Empty DataFrame
# Columns: [Tweet]
# Index: []

# %%
# get tweets from specific user4

user = "ICMRDELHI"
limit = 30

tweets4 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)
for tweet in tweets4:
  print(tweet.full_text)
# Out:
# COVID-19 Testing Update. For more details visit: https://t.co/dI1pqwfJH7 @MoHFW_INDIA @DeptHealthRes @PIB_India @mygovindia @COVIDNewsByMIB #ICMRFIGHTSCOVID19 #IndiaFightsCOVID19 #CoronaUpdatesInIndia #COVID19 #Unite2FightCorona https://t.co/8dVkHtrrwq
# COVID-19 Testing Update. For more details visit: https://t.co/dI1pqwfJH7 @MoHFW_INDIA @DeptHealthRes @PIB_India @mygovindia @COVIDNewsByMIB #ICMRFIGHTSCOVID19 #IndiaFightsCOVID19 #CoronaUpdatesInIndia #COVID19 #Unite2FightCorona https://t.co/fBaAdAySdR
# COVID-19 Testing Update. For more details visit: https://t.co/dI1pqwfJH7 @MoHFW_INDIA @DeptHealthRes @PIB_India @mygovindia @COVIDNewsByMIB #ICMRFIGHTSCOVID19 #IndiaFightsCOVID19 #CoronaUpdatesInIndia #COVID19 #Unite2FightCorona https://t.co/YJc4ikV9fh
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets4:
    data.append([tweet.full_text])

df4 = pd.DataFrame(data, columns=columns)

print(df4)
# Out:
#                                                 Tweet
# 0   COVID-19 Testing Update. For more details visi...
# 1   COVID-19 Testing Update. For more details visi...
# 2   COVID-19 Testing Update. For more details visi...
# 3   COVID-19 Testing Update. For more details visi...
# 4   COVID-19 Testing Update. For more details visi...
# 5   COVID-19 Testing Update. For more details visi...
# 6   COVID-19 Testing Update. For more details visi...
# 7   COVID-19 Testing Update. For more details visi...
# 8   COVID-19 Testing Update. For more details visi...
# 9   COVID-19 Testing Update. For more details visi...
# 10  COVID-19 Testing Update. For more details visi...

# %%
# get tweets from specific user5

user = "COVID19Tracking"
limit = 30


tweets5 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets5:
  print(tweet.full_text)

# %%
columns = ['Tweet']
data = []

for tweet in tweets5:
    data.append([tweet.full_text])

df5 = pd.DataFrame(data, columns=columns)

print(df5)
# Out:
# Empty DataFrame
# Columns: [Tweet]
# Index: []

# %%
# get tweets from specific user6

user = "Medscape"
limit = 30


tweets6 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets6:
  print(tweet.full_text)
# Out:
# Data suggests a nearly 25% increased risk of breast cancer risk + 60% increased risk for prostate cancer among those who frequently consumed nitrate-containing products. https://t.co/hV480Nq2aE
# What happens when "hesitancy" turns into suspicion and skepticism of the healthcare system? https://t.co/vpepsnqaPc https://t.co/8SmoB5woiE
# California naturopath recently pleaded guilty to falsifying COVID-19 vaccination cards and offering patients lifelong protection from COVID-19. https://t.co/D1fXUTr1uK
# Men who regularly used #Viagra were more likely to suffer visual impairment, including retinal detachment and blindness, large cohort study finds. #TwitteRx https://t.co/uONgloGCeF https://t.co/FMlQuC2Up3
# Update your knowledge of anticonvulsants -- a widely used group of drugs with this short quiz. https://t.co/pZuSYXT7Mj #TwitteRx
# Read about the various types of #bluntforcetrauma and their potential complications: https://t.co/DfslJaZpe6
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets6:
    data.append([tweet.full_text])

df6 = pd.DataFrame(data, columns=columns)

print(df6)
# Out:
#                                                 Tweet
# 0   Data suggests a nearly 25% increased risk of b...
# 1   What happens when "hesitancy" turns into suspi...
# 2   California naturopath recently pleaded guilty ...
# 3   Men who regularly used #Viagra were more likel...
# 4   Update your knowledge of anticonvulsants -- a ...
# 5   Read about the various types of #bluntforcetra...
# 6   RLS occurred in approximately 40% of adults wi...
# 7   DOJ will appeal a Florida judge's ruling Monda...
# 8   The risk of #myocarditis is higher with the Mo...
# 9   Despite popular belief that T1D is a disease t...
# 10  Antidepressant use is not associated with sign...
# 11  The number of suspicious prescriptions involvi...
# 12  Patients with AML and high-risk MDS had strong...
# 13  FDA throws the flag against 12 companies selli...
# 14  Bird flu, which has been spreading across the ...
# 15  Simplified BP approaches may be appropriate fo...
# ...

# %%
# get tweets from specific user7

user = "SkyNews"
limit = 30


tweets7 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets7:
  print(tweet.full_text)
# Out:
# Russian forces will seize the strategically important Ukrainian port city of Mariupol today, a top ally of Vladimir Putin has claimed after Ukraine warned its forces are unable to "hold out for much longer" https://t.co/Y0N9cuOOHG
# The Kremlin has declared that capturing the Donbas region of eastern Ukraine is now its main goal. But will they succeed?
#
# On the Sky News #Daily podcast with @LeahBoleto, @haynesdeborah joins us in Kyiv, and @Stone_SkyNews is in Dnipro, but has just been in the Donbas region.
# Queen Barbie doll among souvenirs to celebrate Platinum Jubilee https://t.co/1554Sp4vIR
# Labour leader Sir Keir Starmer proceeds with his opening statement in the Commons by saying he "seeks to defend the simple principle that honesty, integrity and telling the truth matter in our politics".
#
# https://t.co/cpsQowQBvI
#
# 📺 Sky 501, Virgin 602, Freeview 233 and YouTube https://t.co/9LUM0TM6dG
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets7:
    data.append([tweet.full_text])

df7 = pd.DataFrame(data, columns=columns)

print(df7)
# Out:
#                                                 Tweet
# 0   Russian forces will seize the strategically im...
# 1   The Kremlin has declared that capturing the Do...
# 2   Queen Barbie doll among souvenirs to celebrate...
# 3   Labour leader Sir Keir Starmer proceeds with h...
# 4   RT @SkyNewsPolitics: Conservative MPs will be ...
# 5   BREAKING: Labour leader Sir Keir Starmer has w...
# 6   The Florida Senate has passed a bill that woul...
# 7   Israeli fighter jets have carried out airstrik...
# 8   Government drops order to Tory MPs to block pa...
# 9   Watch live: MPs debate and vote on whether the...
# 10  The industrial complex in Mariupol - the last ...
# 11  Nestle, the maker of KitKat chocolate bars and...
# 12  Erik ten Hag: Manchester United appoint Ajax b...
# 13  The Band of the Coldstream Guards play 'Happy ...
# 14  Novak Djokovic criticises 'crazy' Wimbledon ba...
# 15  Car insurance costs are predicted to continue ...
# ...

# %%
# get tweets from specific user8

user = "NCDCgov"
limit = 30


tweets8 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)
for tweet in tweets8:
  print(tweet.full_text)
# Out:
# RT @nighealthwatch: #COVID19 will not be the last disease with the potential to grow into a pandemic. How do we ensure that #Nigeria is wel…
# Masks are still a key way to prevent the spread of #COVID19.
#
# When you wear a mask in public domains and indoor gatherings.
#
# Ensure it's fitted properly over your mouth and nose.
#
# #TakeResponsibility https://t.co/12S2OUhoAK
# This report includes:
#
# ▪️Data for 19th and 20th April 2022
# ▪️6 States with zero cases reported: Delta, Kaduna, Kano, Plateau, Rivers and Sokoto
#
# For a breakdown of cases by state visit https://t.co/zQrpNeOfet https://t.co/k93f2tY4gB
# 9 new confirmed cases of #COVID19Nigeria;
#
# FCT-6
# Lagos-3
#
# 255,679 confirmed
# 249,886 discharged
# 3,143 deaths
#
# #TakeResponsibility https://t.co/2bb0dtNSjd
# RT @NphcdaNG: Hello Nigerians, here is an instructional video to guide you through your COVID-19 vaccination card verification. Please foll…
# 📚
#
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets8:
    data.append([tweet.full_text])

df8 = pd.DataFrame(data, columns=columns)

print(df8)
# Out:
#                                                 Tweet
# 0   RT @nighealthwatch: #COVID19 will not be the l...
# 1   Masks are still a key way to prevent the sprea...
# 2   This report includes:\n\n▪️Data for 19th and 2...
# 3   9 new confirmed cases of #COVID19Nigeria;\n\nF...
# 4   RT @NphcdaNG: Hello Nigerians, here is an inst...
# 5   📚\n\n#AntimicrobialResistance poses one of the...
# 6   📚\n\n#AntimicrobialResistance poses one of the...
# 7   Here are simple &amp; effective actions to tak...
# 8   In this article, we share Nigeria's experience...
# 9   In response to lessons learned from the 2003 s...
# 10  #NCDCPublication📚\n\nSeveral disease outbreaks...
# 11  #Lassafever is a zoonotic disease transmitted ...
# 12  Read more in the Nigerian Manual of Infection ...
# 13  The overall goal of Infection Prevention &amp;...
# 14  This report includes:\n\n▪️Data for 16th to 18...
# 15  22 new confirmed cases of #COVID19Nigeria;\n\n...
# ...

# %%
# get tweets from specific user9

user = "COVIDNewsByMIB"
limit = 30


tweets9 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets9:
  print(tweet.full_text)
# Out:
# #IndiaFightsCorona:
#
# 📍#COVID19 Active Cases in India (As on 21st April, 2022): 13,433
#
# ✅Keep following #COVIDAppropriateBehaviour
#
# ➡️Always wear a mask
# ➡️Wash/sanitize hands regularly
# ➡️Maintain distancing
# ➡️Get yourself fully vaccinated
#
# #We4Vaccine
# #Unite2FightCorona https://t.co/VNba7XeQ19
# #IndiaFightsCorona:
#
# 📍𝑴𝒐𝒓𝒆 𝒕𝒉𝒂𝒏 15 lakh (15,47,288) 𝒗𝒂𝒄𝒄𝒊𝒏𝒆 𝒅𝒐𝒔𝒆𝒔 𝒂𝒅𝒎𝒊𝒏𝒊𝒔𝒕𝒆𝒓𝒆𝒅 𝒊𝒏 𝒕𝒉𝒆 𝒍𝒂𝒔𝒕 24 𝒉𝒐𝒖𝒓𝒔.
#
# ☑️Together we can win the battle against #COVID19.
#
# #We4Vaccine
# #LargestVaccinationDrive
# #Unite2FightCorona https://t.co/uNIEnxskQG
# #IndiaFightsCorona:
#
# 📍New #COVID19 cases in last 24 hours (As on 21st April, 2022): 2,380
#
# ✅Keep following #COVIDAppropriateBehaviour
#
# ➡️Always wear a mask
# ➡️Wash/sanitize hands regularly
# ➡️Maintain distancing
# ➡️Get yourself fully vaccinated
#
# #We4Vaccine
# #Unite2FightCorona https://t.co/MyvjUMixdZ
# #IndiaFightsCorona:
#
# ➡️1,547 patients recovered during last 24 hours
#
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets9:
    data.append([tweet.full_text])

df9 = pd.DataFrame(data, columns=columns)

print(df9)
# Out:
#                                                 Tweet
# 0   #IndiaFightsCorona:\n\n📍#COVID19 Active Cases ...
# 1   #IndiaFightsCorona:\n\n📍𝑴𝒐𝒓𝒆 𝒕𝒉𝒂𝒏 15 lakh (15,...
# 2   #IndiaFightsCorona:\n\n📍New #COVID19 cases in ...
# 3   #IndiaFightsCorona: \n\n➡️1,547 patients recov...
# 4   #IndiaFightsCorona:\n\n➡️186.90 crore vaccine ...
# 5   #IndiaFightsCorona: \n\n➡️Active caseload stan...
# 6   #IndiaFightsCorona:\n\n#COVID19 UPDATE (As on ...
# 7   #IndiaFightsCorona:\n\n📍More than 4 Lakh (4,21...
# 8   #IndiaFightsCorona:\n\n📍#COVID19 Active Cases ...
# 9   #IndiaFightsCorona:\n\n📍𝑴𝒐𝒓𝒆 𝒕𝒉𝒂𝒏 17 lakh (17,...
# 10  #IndiaFightsCorona:\n\n📍New #COVID19 cases in ...
# 11  #IndiaFightsCorona:\n\n➡️ Over 83.29 Cr COVID ...
# 12  #IndiaFightsCorona:\n\n➡️ 2,067 New Cases repo...
# 13  #IndiaFightsCorona:\n\n➡️ India's Recovery Rat...
# 14  #IndiaFightsCorona:\n\n➡️ India's Active Casel...
# 15  #IndiaFightsCorona:\n\n➡️ India’s Cumulative #...
# ...

# %%
# get tweets from specific user10

user = "MoHFW_INDIA"
limit = 30


tweets10 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets10:
  print(tweet.full_text)
# Out:
# #4YearsofHWCs
#
# ➡️ More than 71,000 ABHA Health IDs created; 17,000 PMJAY Golden Cards issued and 36,000 teleconsultations done
# #4YearsofHWCs
#
# ➡️More than 4 lakh people participated in Ayushman Bharat block level Health Melas on 20th April; 484 blocks organized Health Melas on day three across the country.
#
# https://t.co/BJcQjGqEnH https://t.co/XzkkoNjrjL
# राजस्थान के जोधपुर जिले के #बालेसर खण्ड में आयोजित ब्लॉक हेल्थ मेले में लाभार्थी श्रीमती रौनक जी ने स्वास्थ्य सेवाओं का लाभ लेकर अपने अनुभव साझा किए।
# #4YearsofHWC
# #AzadiKaAmritMahotsav
#
# @mansukhmandviya @ianuragthakur @DrBharatippawar @PIB_India @mygovindia @AmritMahotsav https://t.co/bzuX549A3z
# #4YearsofHWC
#
# डिजिटल मिशन के अंतर्गत आयुषमान भारत का लक्ष्य है कि देश के हर नागरिक का स्वास्थ्य खाता हो जिसके माध्यम से नागरिकों के स्वास्थ्य इतिहास को डिजिटली संरक्षित रखा जाएगा।
# - डॉ. @MansukhMandviya, केंद्रीय स्वास्थ्य एवं परिवार कल्याण मंत्री
#
# @ianuragthakur https://t.co/Pr1lQLseeG
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets10:
    data.append([tweet.full_text])

df10 = pd.DataFrame(data, columns=columns)

print(df10)
# Out:
#                                                 Tweet
# 0   #4YearsofHWCs\n\n➡️ More than 71,000 ABHA Heal...
# 1   #4YearsofHWCs\n\n➡️More than 4 lakh people par...
# 2   राजस्थान के जोधपुर जिले के #बालेसर खण्ड में आय...
# 3   #4YearsofHWC \n\nडिजिटल मिशन के अंतर्गत आयुषमा...
# 4   राजस्थान के जोधपुर जिले के #बालेसर खण्ड में आय...
# 5   RT @mansukhmandviya: The entire nation has imm...
# 6   #LargestVaccineDrive\n#Unite2FightCorona https...
# 7   RT @mansukhmandviya: Glad to be part of the 62...
# 8   RT @mansukhmandviya: Learning, Research &amp; ...
# 9   RT @mansukhmandviya: हमारी ट्रेडिशनल मेडिसिन, ...
# 10  RT @OfficeOf_MM: हमारी ट्रेडिशनल मेडिसिन, आयुष...
# 11  RT @OfficeOf_MM: Minister Dr @MansukhMandviya ...
# 12  #Unite2FightCorona\n#LargestVaccineDrive https...
# 13  #Unite2FightCorona\n#LargestVaccineDrive https...
# 14  इन मुश्किल हालत में, अगर आपको दो हफ़्तों से ज्...
# 15  In these difficult circumstances, it’s importa...
# ...

# %%
# get tweets from specific user11

user = "mygovindia"
limit = 30


tweets11 = api.user_timeline(screen_name=user, count=limit, tweet_mode="extended", since_id=1477226298560950276, exclude_replies=True)

for tweet in tweets11:
  print(tweet.full_text)
# Out:
# A major boost for Make in India! #AatmaNirbharBharat https://t.co/dBTiD8Ebif
# People across India are participating in the #SabkaVikasMahaQuiz - the biggest quiz contest of the year! What are you waiting for? Take the quiz and stand a chance to win exciting cash rewards. Visit: https://t.co/DtNHH86skq https://t.co/JbusSQ7j7x
# #CivilServicesDay https://t.co/RvlZq6ska2
# #CivilServicesDay https://t.co/ypf2MU35dx
# PM @narendramodi conferred the Prime Minister’s Awards for excellence in Public Administration today. Check out the key highlights from his speech! #CivilServicesDay https://t.co/h5FFHVUIox
# Celebrating the golden age of the Indian startup ecosystem! #AatmaNirbharBharat https://t.co/UmGIKcnCfY
# RT @mopr_goi: पंचायती राज दिवस का ये दिन ग्रामीण भारत के #नवनिर्माण के #संकल्पों को दोहराने का एक महत्वपूर्ण अवसर होता है। ये दिन हमारी…
# ...

# %%
columns = ['Tweet']
data = []

for tweet in tweets11:
    data.append([tweet.full_text])

df11 = pd.DataFrame(data, columns=columns)

print(df11)
# Out:
#                                                 Tweet
# 0   A major boost for Make in India! #AatmaNirbhar...
# 1   People across India are participating in the #...
# 2           #CivilServicesDay https://t.co/RvlZq6ska2
# 3           #CivilServicesDay https://t.co/ypf2MU35dx
# 4   PM @narendramodi conferred the Prime Minister’...
# 5   Celebrating the golden age of the Indian start...
# 6   RT @mopr_goi: पंचायती राज दिवस का ये दिन ग्राम...
# 7   Thank you, Sanjay for participating in the big...
# 8   हमारा हर फैसला देश की एकता और अखंडता को बढ़ाने...
# 9   आज़ादी के 75 वर्ष से 100 वर्ष की यात्रा में हम...
# 10  शासन व्यवस्था के बाहर भी समाज के सामर्थ्य की त...
# 11  गवर्नेंस में रिफॉर्म्स नित्य और सहज प्रक्रिया ...
# 12  Our UPI is getting global appreciation. But ar...
# 13  We are tangled in bigger things that we tend t...
# 14  When we expect the nation to eradicate single ...
# 15  Governance Reforms should your goal. You shoul...
# ...

# %%
# create joined DataFrame

frames = [df, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11]

result = pd.concat(frames)

print(result)
# Out:
#                                                 Tweet
# 0   RT @WHOUkraine: .@WHO is providing generators ...
# 1   RT @DrTedros: Namaste 🙏 Prime Minister @narend...
# 2   RT @DrTedros: Pleased to meet #Mauritius Prime...
# 3   RT @DrTedros: Devastated by the reports of att...
# 4   RT @DrTedros: By working together to make the ...
# ..                                                ...
# 25  Every decision taken by a citizen should be ta...
# 26  All our efforts should be aligned to one thing...
# 27  3. Maintain the harmony &amp; integrity of the...
# 28  Today, on #CivilServicesDay I would like to st...
# 29  When you try to proactively learn from people,...
#
# [263 rows x 1 columns]

# %%
#save output
from google.colab import drive
drive.mount('drive')

result.to_csv('/content/drive/MyDrive/Final Project/COVID-fake-news-detection/New data/Data/real_data_raw.csv', encoding='utf-8')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

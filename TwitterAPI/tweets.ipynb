# %%
import os
import tweepy as tw
import pandas as pd
from twitter_authentication import consumer_key
from twitter_authentication import consumer_secret
from twitter_authentication import access_token
from twitter_authentication import access_token_secret

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Define the search term and the date_since date as variables
search_words = "#covid"
date_since = "2022-04-01"

# %%
# Collect tweets
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)

# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @jenniferatntd: From “#PreciseControl” to #Lockdown: What Happened in Between? #XiJinping's Hair Turns Grey Overnight
# A lot to see here!…
# For children aged under 5, the incidence rate of #Covid-19 infection is higher with the omicron versus the delta va… https://t.co/vRGCjKXq7r
# RT @SafeEdForAll_UK: 🇬🇧 DfE has ordered schools NOT to give out any more lateral flow tests but to dump them instead. Our school staff, chi…
# RT @SafeEdForAll_UK: 🇬🇧 DfE has ordered schools NOT to give out any more lateral flow tests but to dump them instead. Our school staff, chi…
# RT @lipoftv: My live hit from the @GMA studio this morning on the back and forth day over #Covid in #NYC
